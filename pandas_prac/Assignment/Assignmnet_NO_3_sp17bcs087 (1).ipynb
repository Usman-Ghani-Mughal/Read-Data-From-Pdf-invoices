# %% [markdown]
# # Unzipping dataset.zip

# %%
path_to_zip_file = "H:/study/5th_semester/DataAnylasis/Assignmnet_Data_DataAnalysis_2/dataset.zip"
directory_to_extract_to = "H:/study/5th_semester/DataAnylasis/Assignmnet_Data_DataAnalysis_2/Assignmnet_two_data"
import zipfile
zip_ref = zipfile.ZipFile(path_to_zip_file,'r')
zip_ref.extractall(directory_to_extract_to)
zip_ref.close()

# %%
import pandas as pd
Location = "H:/study/5th_semester/DataAnylasis/Assignmnet_Data_DataAnalysis_2/dataset/smallgradesh.csv"
df = pd.read_csv(Location, header=None)
df = pd.read_csv(Location, names=['Names','Grades'])
df.columns = ['Names','Grades']
df.head()
# Out:
#      Names Grades
# 0     Name  Grade
# 1   Marcia   82.4
# 2   Kadeem   78.2
# 3     Nash   79.3
# 4  Noelani   83.2

# %%
Location = "H:/study/5th_semester/DataAnylasis/Assignmnet_Data_DataAnalysis_2/datasets/gradedata.csv"
df = pd.read_csv(Location)
df.head()
# Out:
#      fname     lname  gender  age  exercise  hours  grade  \
# 0   Marcia      Pugh  female   17         3     10   82.4
# 1   Kadeem  Morrison    male   18         4      4   78.2
# 2     Nash    Powell    male   18         5      9   79.3
# 3  Noelani    Wagner  female   14         2      7   83.2
# 4  Noelani    Cherry  female   18         4     15   87.4
#
#                                     address
# 0   9253 Richardson Road, Matawan, NJ 07747
# 1          33 Spring Dr., Taunton, MA 02780
# 2          41 Hill Avenue, Mentor, OH 44060
# 3        8839 Marshall St., Miami, FL 33125
# 4  8304 Charles Rd., Lewis Center, OH 43035

# %%
Location = "H:/study/5th_semester/DataAnylasis/Assignmnet_Data_DataAnalysis_2/Assignmnet_two_data/dataset/smallgrades.csv"
df = pd.read_csv(Location,names=['Names','Grades'])
df.columns = ['Names','Grades']
df.head()
# Out:
#      Names  Grades
# 0   Marcia    82.4
# 1   Kadeem    78.2
# 2     Nash    79.3
# 3  Noelani    83.2
# 4  Noelani    87.4

# %%
Location = "H:/study/5th_semester/DataAnylasis/Assignmnet_Data_DataAnalysis_2/dataset/all_040_in_01.P1.csv"
df = pd.read_csv(Location)
df.head()
# Out:
#    GEOID  SUMLEV  STATE  COUNTY  CBSA  CSA  NECTA  CNECTA     NAME   POP100  \
# 0      1      40      1     NaN   NaN  NaN    NaN     NaN  Alabama  4779736
#
#      HU100  POP100.2000  HU100.2000  P001001  P001001.2000
# 0  2171853      4447100     1963711  4779736       4447100

# %%
names = ['Bob','Jessica','Mary','John','Mel']
grades = [76,95,77,78,99]
GradeList = list(zip(names,grades))
df = pd.DataFrame(data = GradeList, columns=['Names','Grades'])
df.to_csv('H:/study/5th_semester/DataAnylasis/Assignmnet_Data_DataAnalysis_2/dataset/studentgrades.csv',index=False,header=False)
df.head(1)
# Out:
#   Names  Grades
# 0   Bob      76

# %%
names = ['Bob','John','Mel']
grades = [77,78,99]
bsdegrees = [1,1,1]
msdegrees = [0,0,0]
phddegrees = [1,1,0]
Degrees = list(zip(names,grades,bsdegrees,msdegrees,phddegrees))
colm = ['Names','Grades','BS','MS','PhD']
df = pd.DataFrame(data = Degrees, columns=colm)
df.head()
# Out:
#   Names  Grades  BS  MS  PhD
# 0   Bob      77   1   0    1
# 1  John      78   1   0    1
# 2   Mel      99   1   0    0

# %%
Location = "H:/study/5th_semester/DataAnylasis/Assignmnet_Data_DataAnalysis_2/dataset/gradedata.xlsx"
df = pd.read_excel(Location)
df.head()
# Out:
#      fname     lname  gender  age  exercise  hours  grade  \
# 0   Marcia      Pugh  female   17         3     10   82.4
# 1   Kadeem  Morrison    male   18         4      4   78.2
# 2     Nash    Powell    male   18         5      9   79.3
# 3  Noelani    Wagner  female   14         2      7   83.2
# 4  Noelani    Cherry  female   18         4     15   87.4
#
#                                       address
# 0        7379 Highland Rd. , Dublin, GA 31021
# 1          8 Bayport St. , Honolulu, HI 96815
# 2           Encino, CA 91316, 3 Lilac Street
# 3  Riverview, FL 33569, 9998 North Smith Dr.
# 4   97 SE. Ocean Street , Bethlehem, PA 18015

# %%
df.columns = ['first','last','sex','age','exer','hrs','grd','addr']
df.head()
# Out:
#      first      last     sex  age  exer  hrs   grd  \
# 0   Marcia      Pugh  female   17     3   10  82.4
# 1   Kadeem  Morrison    male   18     4    4  78.2
# 2     Nash    Powell    male   18     5    9  79.3
# 3  Noelani    Wagner  female   14     2    7  83.2
# 4  Noelani    Cherry  female   18     4   15  87.4
#
#                                          addr
# 0        7379 Highland Rd. , Dublin, GA 31021
# 1          8 Bayport St. , Honolulu, HI 96815
# 2           Encino, CA 91316, 3 Lilac Street
# 3  Riverview, FL 33569, 9998 North Smith Dr.
# 4   97 SE. Ocean Street , Bethlehem, PA 18015

# %%
location = "H:/study/5th_semester/DataAnylasis/Assignmnet_Data_DataAnalysis_2/Assignmnet_two_data/dataset/Data_Online/Mastgroups.xls"
df = pd.read_excel(Location)
df.head(1)
# Out:
#     fname lname  gender  age  exercise  hours  grade  \
# 0  Marcia  Pugh  female   17         3     10   82.4
#
#                                 address
# 0  7379 Highland Rd. , Dublin, GA 31021

# %%
Names = ['BOB','Jhon','Mel']
Grades = [89,98,78]
bsdegrees = [1,1,0]
msdegrees = [1,0,0]
phddegrees = [1,0,0]
degress = list(zip(Names,Grades,bsdegrees,msdegrees,phddegrees))
Colm = ['Names','Grades','BS','MS','PhD']

_Names = ['Usman','Noman','Nadeem']
_Grades = [89,98,78]
_bsdegrees = [1,1,0]
_msdegrees = [1,0,0]
_phddegrees = [1,0,0]
_degress = list(zip(_Names,_Grades,_bsdegrees,_msdegrees,_phddegrees))
_Colms = ['Names','Grades','BS','MS','PhD']

df1 = pd.DataFrame(data=degress,columns=Colm)
df2 = pd.DataFrame(data=_degress,columns=_Colms)

write = pd.ExcelWriter("H:/study/5th_semester/DataAnylasis/Assignmnet_Data_DataAnalysis_2/Assignmnet_two_data/dataset/dataframes.xlsx",engine="xlsxwriter")

df1.to_excel(write,sheet_name='Sheet_1')
df2.to_excel(write,sheet_name='Sheet_2')

write.save()

# %%
names = ['Nike','Adidas','New Balance','Puma','Reebok']
prices = [176,59,47,38,99]
PriceList = list(zip(names,prices))
df = pd.DataFrame(data = PriceList,columns=['Names','Prices'])

write = pd.ExcelWriter("H:/study/5th_semester/DataAnylasis/Assignmnet_Data_DataAnalysis_2/Assignmnet_two_data/dataset/my_turn_dataframes.xlsx",engine="xlsxwriter")

df.to_excel(write,sheet_name="sheet1")
write.save()

# %%
alldata = pd.DataFrame()
df = pd.read_excel("H:/study/5th_semester/DataAnylasis/Assignmnet_Data_DataAnalysis_2/Assignmnet_two_data/dataset/gradedata.xlsx")
alldata = alldata.append(df,ignore_index=True)
df = pd.read_excel("H:/study/5th_semester/DataAnylasis/Assignmnet_Data_DataAnalysis_2/Assignmnet_two_data/dataset/data2.xlsx")
alldata = alldata.append(df,ignore_index=True,sort=True)
df = pd.read_excel("H:/study/5th_semester/DataAnylasis/Assignmnet_Data_DataAnalysis_2/Assignmnet_two_data/dataset/data3.xlsx")
alldata = alldata.append(df,ignore_index=True,sort=True)
alldata.describe()
# Out:
#                age     exercise        grade        hours
# count  2200.000000  2000.000000  2200.000000  2000.000000
# mean     16.575455     3.000500    82.595500    10.988500
# std       1.693617     1.423205     9.805204     4.063942
# min      14.000000     0.000000    32.000000     0.000000
# 25%      15.000000     2.000000    75.400000     8.000000
# 50%      17.000000     3.000000    82.750000    11.000000
# 75%      18.000000     4.000000    89.800000    14.000000
# max      19.000000     5.000000   100.000000    20.000000

# %%
import glob
all_data = pd.DataFrame()
for f in glob.glob("H:/study/5th_semester/DataAnylasis/Assignmnet_Data_DataAnalysis_2/Assignmnet_two_data/dataset/data*.xlsx"):
    df = pd.read_excel(f)
    all_data = all_data.append(df,ignore_index=True,sort=True)
all_data.describe()
# Out:
#              BS     Grades        MS       PhD         age       grade
# count  6.000000   6.000000  6.000000  6.000000  300.000000  300.000000
# mean   0.666667  88.333333  0.333333  0.333333   16.456667   82.923333
# std    0.516398   8.959167  0.516398  0.516398    1.700321   10.544576
# min    0.000000  78.000000  0.000000  0.000000   14.000000   65.000000
# 25%    0.250000  80.750000  0.000000  0.000000   15.000000   73.750000
# 50%    1.000000  89.000000  0.000000  0.000000   16.000000   82.000000
# 75%    1.000000  95.750000  0.750000  0.750000   18.000000   92.000000
# max    1.000000  98.000000  1.000000  1.000000   19.000000  100.000000

# %%
import glob
all_data = pd.DataFrame()
for f in glob.glob("H:/study/5th_semester/DataAnylasis/Python Code Pandas/datasets/weekly_call_data/weekdata_*.xlsx"):
    df = pd.read_excel(f)
    all_data = all_data.append(df,ignore_index=True,sort=True)
all_data.describe()
# Out:
#         CallDuration
# count  129588.000000
# mean       12.517147
# std         6.925404
# min         1.000000
# 25%         7.000000
# 50%        13.000000
# 75%        19.000000
# max        24.000000

# %%
from sqlalchemy import create_engine
db_file = r'H:/study/5th_semester/DataAnylasis/Python Code Pandas/datasets/gradedata.db'
engine = create_engine(r"sqlite:///{}"
.format(db_file))
sql = 'SELECT * from test'
'where Grades in (76,77,78)'
sales_data_df = pd.read_sql(sql, engine)
sales_data_df
# Out:
#    index    Names  Grades
# 0      0      Bob      76
# 1      1  Jessica      95
# 2      2     Mary      77
# 3      3     John      78
# 4      4      Mel      99

# %%
sql = "select name from sqlite_master"
"where type = 'table';"
sql = "select * from test;"

# %%
sales_data_df.read_sql?

# %%
from sqlalchemy import create_engine
db_file = r'H:/study/5th_semester/DataAnylasis/Assignmnet_Data_DataAnalysis_2/Assignmnet_two_data/dataset/gradedata.db'
engine = create_engine(r"sqlite:///{}".format(db_file))
sql = 'SELECT * from test'
sales_data_df = pd.read_sql(sql, engine)

# %%
import os
import sqlite3 as lite
db_filename = r'mydb.db'
con = lite.connect(db_filename)
df.to_sql('mytable',
con,
schema=None,
if_exists='replace',
index=True,
index_label=None,
chunksize=None,
dtype=None)
con.close()

# %%
df.to_sql?

# %%
names = ['Bob','Jessica','Mary','John','Mel']
grades = [76,95,77,78,99]
GradeList = list(zip(names,grades))
df = pd.DataFrame(data = GradeList,
columns=['Names', 'Grades'])
df
import os
import sqlite3 as lite
db_filename = r'mydb.db'
con = lite.connect(db_filename)
df.to_sql('mytable',
con,

schema=None,
if_exists='replace',
index=True,
index_label=None,
chunksize=None,
dtype=None)
con.close()


db_file = r'H:/study/5th_semester/DataAnylasis/Assignmnet_Data_DataAnalysis_2/Assignmnet_two_data/dataset/gradedata.db'
engine = create_engine(r"sqlite:///{}"
.format(db_file))
sql = 'SELECT * from test'
'where Grades in (76,77,78)'
sales_data_df = pd.read_sql(sql, engine)
sales_data_df
# Out:
#    index    Names  Grades
# 0      0      Bob      76
# 1      1  Jessica      95
# 2      2     Mary      77
# 3      3     John      78
# 4      4      Mel      99

# %%
from numpy import random
from numpy.random import randint
names = ['Bob','Jessica','Mary','John','Mel']
random.seed(500)
randnames = []
for i in range(1000):
    name = names[randint(low=0,high=len(names))]
    randnames.append(name) 
births = []
for i in range(1000):
    births.append(randint(low=0, high=1000))
BabyDataSet2 = list(zip(randnames,births))
df = pd.DataFrame(data = BabyDataSet2,
columns=['Names', 'Births'])
df
# Out:
#        Names  Births
# 0       Mary     968
# 1    Jessica     155
# 2    Jessica      77
# 3        Bob     578
# 4    Jessica     973
# 5    Jessica     124
# 6    Jessica     155
# 7       Mary     403
# 8       Mary     199
# 9       Mary     191
# 10      John     769
# 11       Bob      88
# 12       Bob      43
# 13      Mary     393
# 14      Mary     164
# 15      John      45
# 16       Mel     148
# 17      Mary     609
# 18       Mel     134
# 19      John     726
# 20      John     106
# 21       Mel     355
# 22   Jessica     774
# 23      John     214
# 24   Jessica     732
# 25      Mary     362
# 26      Mary     682
# 27      John     141
# 28   Jessica     433
# 29       Bob     892
# ..       ...     ...
# 970  Jessica     572
# 971  Jessica     639
# 972  Jessica     566
# 973      Mel     739
# 974      Bob      78
# 975     John     150
# 976     Mary     463
# 977      Bob     715
# 978     John     118
# 979      Mel     122
# 980  Jessica     276
# ...

# %%
randnames = []
for i in range(250):
    name = names[randint(low=0,high=len(names))]
    randnames.append(name)
number = []
for i in range(250):
    number.append(randint(low=1, high=25))
Parkingtickets = list(zip(randnames,number))
df = pd.DataFrame(data = Parkingtickets,
columns=['Names', 'Number'])
df.head(1)
# Out:
#   Names  Number
# 0   Mel      18

# %%
import pandas as pd
Location = "H:/study/5th_semester/DataAnylasis/Assignmnet_Data_DataAnalysis_2/Assignmnet_two_data/dataset/gradedata.csv"
df = pd.read_csv(Location)
meangrade = df['grade'].mean()
stdgrade = df['grade'].std()
toprange = meangrade + stdgrade * 1.96
botrange = meangrade - stdgrade * 1.96
copydf = df
copydf = copydf.drop(copydf[copydf['grade']
> toprange].index)
copydf = copydf.drop(copydf[copydf['grade']
< botrange].index)
copydf
# Out:
#           fname      lname  gender  age  exercise  hours  grade  \
# 0        Marcia       Pugh  female   17         3     10   82.4
# 1        Kadeem   Morrison    male   18         4      4   78.2
# 2          Nash     Powell    male   18         5      9   79.3
# 3       Noelani     Wagner  female   14         2      7   83.2
# 4       Noelani     Cherry  female   18         4     15   87.4
# 5          Neil    Whitley    male   16         5     16   88.7
# 6         Nelle     Golden  female   17         1      9   80.2
# 7       Armando    Hoffman    male   17         5     18   95.1
# 8       Illiana      Rojas  female   15         5      9   76.5
# 9          Neil     Wooten    male   15         3     15   89.7
# 10       Daquan    Alvarez    male   16         2     13   85.2
# 11         Nola  Velazquez  female   15         2     10   75.3
# 12        Quinn     Warren  female   14         4     12   80.7
# 13      Frances  Velasquez  female   15         2     15   84.2
# ...

# %%
import pandas as pd
Location = "H:/study/5th_semester/DataAnylasis/Assignmnet_Data_DataAnalysis_2/Assignmnet_two_data/dataset/gradedata.csv"
df = pd.read_csv(Location)
q1 = df['grade'].quantile(.25)
q3 = df['grade'].quantile(.75)
iqr = q3-q1
toprange = q3 + iqr * 1.5
botrange = q1 - iqr * 1.5
copydf = df
copydf = copydf.drop(copydf[copydf['grade']
> toprange].index)
copydf = copydf.drop(copydf[copydf['grade']
< botrange].index)
copydf
# Out:
#           fname      lname  gender  age  exercise  hours  grade  \
# 0        Marcia       Pugh  female   17         3     10   82.4
# 1        Kadeem   Morrison    male   18         4      4   78.2
# 2          Nash     Powell    male   18         5      9   79.3
# 3       Noelani     Wagner  female   14         2      7   83.2
# 4       Noelani     Cherry  female   18         4     15   87.4
# 5          Neil    Whitley    male   16         5     16   88.7
# 6         Nelle     Golden  female   17         1      9   80.2
# 7       Armando    Hoffman    male   17         5     18   95.1
# 8       Illiana      Rojas  female   15         5      9   76.5
# 9          Neil     Wooten    male   15         3     15   89.7
# 10       Daquan    Alvarez    male   16         2     13   85.2
# 11         Nola  Velazquez  female   15         2     10   75.3
# 12        Quinn     Warren  female   14         4     12   80.7
# 13      Frances  Velasquez  female   15         2     15   84.2
# ...

# %%
df = pd.read_csv("H:/study/5th_semester/DataAnylasis/Assignmnet_Data_DataAnalysis_2/Assignmnet_two_data/dataset/gradedata.csv")
df.head()
# Out:
#      fname     lname  gender  age  exercise  hours  grade  \
# 0   Marcia      Pugh  female   17         3     10   82.4
# 1   Kadeem  Morrison    male   18         4      4   78.2
# 2     Nash    Powell    male   18         5      9   79.3
# 3  Noelani    Wagner  female   14         2      7   83.2
# 4  Noelani    Cherry  female   18         4     15   87.4
#
#                                     address
# 0   9253 Richardson Road, Matawan, NJ 07747
# 1          33 Spring Dr., Taunton, MA 02780
# 2          41 Hill Avenue, Mentor, OH 44060
# 3        8839 Marshall St., Miami, FL 33125
# 4  8304 Charles Rd., Lewis Center, OH 43035

# %%
df_no_missing = df.dropna()
df_no_missing
# Out:
# Empty DataFrame
# Columns: [fname, lname, gender, age, exercise, hours, grade, address, newcol]
# Index: []

# %%
df['newcol'] = np.nan
df.head()
# Out:
#      fname     lname  gender  age  exercise  hours  grade  \
# 0   Marcia      Pugh  female   17         3     10   82.4
# 1   Kadeem  Morrison    male   18         4      4   78.2
# 2     Nash    Powell    male   18         5      9   79.3
# 3  Noelani    Wagner  female   14         2      7   83.2
# 4  Noelani    Cherry  female   18         4     15   87.4
#
#                                     address  newcol
# 0   9253 Richardson Road, Matawan, NJ 07747     NaN
# 1          33 Spring Dr., Taunton, MA 02780     NaN
# 2          41 Hill Avenue, Mentor, OH 44060     NaN
# 3        8839 Marshall St., Miami, FL 33125     NaN
# 4  8304 Charles Rd., Lewis Center, OH 43035     NaN

# %%
df.dropna(axis=1, how='all')
# Out:
#           fname      lname  gender  age  exercise  hours  grade  \
# 0        Marcia       Pugh  female   17         3     10   82.4
# 1        Kadeem   Morrison    male   18         4      4   78.2
# 2          Nash     Powell    male   18         5      9   79.3
# 3       Noelani     Wagner  female   14         2      7   83.2
# 4       Noelani     Cherry  female   18         4     15   87.4
# 5          Neil    Whitley    male   16         5     16   88.7
# 6         Nelle     Golden  female   17         1      9   80.2
# 7       Armando    Hoffman    male   17         5     18   95.1
# 8       Illiana      Rojas  female   15         5      9   76.5
# 9          Neil     Wooten    male   15         3     15   89.7
# 10       Daquan    Alvarez    male   16         2     13   85.2
# 11         Nola  Velazquez  female   15         2     10   75.3
# 12        Quinn     Warren  female   14         4     12   80.7
# 13      Frances  Velasquez  female   15         2     15   84.2
# ...

# %%
df.fillna(0)
# Out:
#           fname      lname  gender  age  exercise  hours  grade  \
# 0        Marcia       Pugh  female   17         3     10   82.4
# 1        Kadeem   Morrison    male   18         4      4   78.2
# 2          Nash     Powell    male   18         5      9   79.3
# 3       Noelani     Wagner  female   14         2      7   83.2
# 4       Noelani     Cherry  female   18         4     15   87.4
# 5          Neil    Whitley    male   16         5     16   88.7
# 6         Nelle     Golden  female   17         1      9   80.2
# 7       Armando    Hoffman    male   17         5     18   95.1
# 8       Illiana      Rojas  female   15         5      9   76.5
# 9          Neil     Wooten    male   15         3     15   89.7
# 10       Daquan    Alvarez    male   16         2     13   85.2
# 11         Nola  Velazquez  female   15         2     10   75.3
# 12        Quinn     Warren  female   14         4     12   80.7
# 13      Frances  Velasquez  female   15         2     15   84.2
# ...

# %%
df["grade"].fillna(df["grade"].mean(), inplace=True)

# %%
df["grade"].fillna(df.groupby("gender")
["grade"].transform("mean"), inplace=True)

# %%
df[df['age'].notnull() & df['gender'].notnull()]
# Out:
#           fname      lname  gender  age  exercise  hours  grade  \
# 0        Marcia       Pugh  female   17         3     10   82.4
# 1        Kadeem   Morrison    male   18         4      4   78.2
# 2          Nash     Powell    male   18         5      9   79.3
# 3       Noelani     Wagner  female   14         2      7   83.2
# 4       Noelani     Cherry  female   18         4     15   87.4
# 5          Neil    Whitley    male   16         5     16   88.7
# 6         Nelle     Golden  female   17         1      9   80.2
# 7       Armando    Hoffman    male   17         5     18   95.1
# 8       Illiana      Rojas  female   15         5      9   76.5
# 9          Neil     Wooten    male   15         3     15   89.7
# 10       Daquan    Alvarez    male   16         2     13   85.2
# 11         Nola  Velazquez  female   15         2     10   75.3
# 12        Quinn     Warren  female   14         4     12   80.7
# 13      Frances  Velasquez  female   15         2     15   84.2
# ...

# %%
names = ['Bob','Jessica','Mary','John','Mel']
grades = [76,-2,77,78,101]
GradeList = list(zip(names,grades))
df = pd.DataFrame(data = GradeList,
columns=['Names', 'Grades'])
df.head(1)
# Out:
#   Names  Grades
# 0   Bob      76

# %%
df.loc[df['Grades'] <= 100]
# Out:
#      Names  Grades
# 0      Bob      76
# 1  Jessica      -2
# 2     Mary      77
# 3     John      78

# %%
df.loc[(df['Grades'] >= 100,'Grades')] = 100

# %%
df.loc[(df['Grades'] >= 100,'Grades')] = 0

# %%
import pandas as pd
names = ['Jan','John','Bob','Jan','Mary','Jon','Mel','Mel']
grades = [95,78,76,95,77,78,99,100]
GradeList = list(zip(names,grades))
df = pd.DataFrame(data = GradeList,
columns=['Names', 'Grades'])
df.head()
# Out:
#   Names  Grades
# 0   Jan      95
# 1  John      78
# 2   Bob      76
# 3   Jan      95
# 4  Mary      77

# %%
df.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# 4    False
# 5    False
# 6    False
# 7    False
# dtype: bool

# %%
df.drop_duplicates()
# Out:
#   Names  Grades
# 0   Jan      95
# 1  John      78
# 2   Bob      76
# 4  Mary      77
# 5   Jon      78
# 6   Mel      99
# 7   Mel     100

# %%
df.drop_duplicates(['Names'], keep='last')
# Out:
#   Names  Grades
# 1  John      78
# 2   Bob      76
# 3   Jan      95
# 4  Mary      77
# 5   Jon      78
# 7   Mel     100

# %%
Location = "H:/study/5th_semester/DataAnylasis/Assignmnet_Data_DataAnalysis_2/Assignmnet_two_data/dataset/gradedata.csv"
df = pd.read_csv(Location)
df.head()
# Out:
#      fname     lname  gender  age  exercise  hours  grade  \
# 0   Marcia      Pugh  female   17         3     10   82.4
# 1   Kadeem  Morrison    male   18         4      4   78.2
# 2     Nash    Powell    male   18         5      9   79.3
# 3  Noelani    Wagner  female   14         2      7   83.2
# 4  Noelani    Cherry  female   18         4     15   87.4
#
#                                     address
# 0   9253 Richardson Road, Matawan, NJ 07747
# 1          33 Spring Dr., Taunton, MA 02780
# 2          41 Hill Avenue, Mentor, OH 44060
# 3        8839 Marshall St., Miami, FL 33125
# 4  8304 Charles Rd., Lewis Center, OH 43035

# %%
import string
exclude = set(string.punctuation)
def remove_punctuation(x):
    try:
        x = ''.join(ch for ch in x if ch not in exclude)
    except:
        pass
    return x
df.address = df.address.apply(remove_punctuation)
df.head()
# Out:
#      fname     lname  gender  age  exercise  hours  grade  \
# 0   Marcia      Pugh  female   17         3     10   82.4
# 1   Kadeem  Morrison    male   18         4      4   78.2
# 2     Nash    Powell    male   18         5      9   79.3
# 3  Noelani    Wagner  female   14         2      7   83.2
# 4  Noelani    Cherry  female   18         4     15   87.4
#
#                                  address
# 0  9253 Richardson Road Matawan NJ 07747
# 1          33 Spring Dr Taunton MA 02780
# 2         41 Hill Avenue Mentor OH 44060
# 3        8839 Marshall St Miami FL 33125
# 4  8304 Charles Rd Lewis Center OH 43035

# %%
Location = "H:/study/5th_semester/DataAnylasis/Assignmnet_Data_DataAnalysis_2/Assignmnet_two_data/dataset/gradedata.csv"
df = pd.read_csv(Location)
df.head()
# Out:
#      fname     lname  gender  age  exercise  hours  grade  \
# 0   Marcia      Pugh  female   17         3     10   82.4
# 1   Kadeem  Morrison    male   18         4      4   78.2
# 2     Nash    Powell    male   18         5      9   79.3
# 3  Noelani    Wagner  female   14         2      7   83.2
# 4  Noelani    Cherry  female   18         4     15   87.4
#
#                                     address
# 0   9253 Richardson Road, Matawan, NJ 07747
# 1          33 Spring Dr., Taunton, MA 02780
# 2          41 Hill Avenue, Mentor, OH 44060
# 3        8839 Marshall St., Miami, FL 33125
# 4  8304 Charles Rd., Lewis Center, OH 43035

# %%
import pandas as pd
names = ['Bob','Jessica','Mary','John','Mel']
grades = [76,95,77,78,99]
bsdegrees = [1,1,0,0,1]
msdegrees = [2,1,0,0,0]
phddegrees = [0,1,0,0,0]
bdates = ['1/1/1945','10/21/76','3/3/90',
'04/30/1901','1963-09-01']
GradeList = list(zip(names,grades,bsdegrees,msdegrees,phddegrees,bdates))
columns=['Names','Grades','BS','MS','PhD',"bdates"]
df = pd.DataFrame(data = GradeList, columns=columns)
df.head()
# Out:
#      Names  Grades  BS  MS  PhD      bdates
# 0      Bob      76   1   2    0    1/1/1945
# 1  Jessica      95   1   1    1    10/21/76
# 2     Mary      77   0   0    0      3/3/90
# 3     John      78   0   0    0  04/30/1901
# 4      Mel      99   1   0    0  1963-09-01

# %%
def standardize_date(thedate):
    df.bdates = df.bdates.apply(standardize_date)
df.head()
# Out:
#      Names  Grades  BS  MS  PhD      bdates
# 0      Bob      76   1   2    0    1/1/1945
# 1  Jessica      95   1   1    1    10/21/76
# 2     Mary      77   0   0    0      3/3/90
# 3     John      78   0   0    0  04/30/1901
# 4      Mel      99   1   0    0  1963-09-01

# %%
names = ['Bob','Jessica','Mary','John','Mel']
grades = [76,95,77,78,99]
bsdegrees = [1,1,0,0,1]
msdegrees = [2,1,0,0,0]
phddegrees = [0,1,0,0,0]
ssns = ['867-53-0909','333-22-4444','123-12-1234',
'777-93-9311','123-12-1423']
GradeList = list(zip(names,grades,bsdegrees,msdegrees,phddegrees,ssns))
columns=['Names','Grades','BS','MS','PhD',"ssn"]
df = pd.DataFrame(data = GradeList, columns=columns)
df.head()
# Out:
#      Names  Grades  BS  MS  PhD          ssn
# 0      Bob      76   1   2    0  867-53-0909
# 1  Jessica      95   1   1    1  333-22-4444
# 2     Mary      77   0   0    0  123-12-1234
# 3     John      78   0   0    0  777-93-9311
# 4      Mel      99   1   0    0  123-12-1423

# %%
def right(s, amount):
    return s[-amount]
def standardize_ssn(ssn):
    try:
        ssn = ssn.replace("-","")
        ssn = "".join(ssn.split())
        if len(ssn)<9 and ssn != 'Missing':
            ssn="000000000" + ssn
            ssn=right(ssn,9)
    except:
        pass
        return ssn
        df.ssn = df.ssn.apply(standardize_ssn)
        df.head()

# %%
Location = "H:/study/5th_semester/DataAnylasis/Assignmnet_Data_DataAnalysis_2/Assignmnet_two_data/dataset/gradedata.csv"
df = pd.read_csv(Location)
df.head()
# Out:
#      fname     lname  gender  age  exercise  hours  grade  \
# 0   Marcia      Pugh  female   17         3     10   82.4
# 1   Kadeem  Morrison    male   18         4      4   78.2
# 2     Nash    Powell    male   18         5      9   79.3
# 3  Noelani    Wagner  female   14         2      7   83.2
# 4  Noelani    Cherry  female   18         4     15   87.4
#
#                                     address
# 0   9253 Richardson Road, Matawan, NJ 07747
# 1          33 Spring Dr., Taunton, MA 02780
# 2          41 Hill Avenue, Mentor, OH 44060
# 3        8839 Marshall St., Miami, FL 33125
# 4  8304 Charles Rd., Lewis Center, OH 43035

# %%
bins = [0, 60, 70, 80, 90, 100]
group_names = ['F', 'D', 'C', 'B', 'A']

# %%
df['lettergrade'] = pd.cut(df['grade'], bins,
labels=group_names)
df.head(1)
# Out:
#     fname lname  gender  age  exercise  hours  grade  \
# 0  Marcia  Pugh  female   17         3     10   82.4
#
#                                    address lettergrade
# 0  9253 Richardson Road, Matawan, NJ 07747           B

# %%
pd.value_counts(df['lettergrade'])
# Out:
# B    737
# C    580
# A    475
# D    193
# F     15
# Name: lettergrade, dtype: int64

# %%
df['graderanked'] = df['grade'].rank(ascending=1)
df.tail()
# Out:
#           fname     lname  gender  age  exercise  hours  grade  \
# 1995       Cody  Shepherd    male   19         1      8   80.1
# 1996  Geraldine  Peterson  female   16         4     18  100.0
# 1997   Mercedes      Leon  female   18         3     14   84.9
# 1998     Lucius   Rowland    male   16         1      7   69.1
# 1999      Linus    Morris    male   19         4     10   79.6
#
#                                           address lettergrade  graderanked
# 1995        982 West Street, Alexandria, VA 22304           B        794.0
# 1996   78 Morris Street, East Northport, NY 11731           A       1957.0
# 1997        30 Glenridge Rd., Bountiful, UT 84010           B       1158.5
# 1998  342 West Meadowbrook Lane, Helena, MT 59601           D        180.0
# 1999       81 Homestead Drive, Voorhees, NJ 08043           C        770.0

# %%
df[df['graderanked'] < 21]
# Out:
#            fname       lname  gender  age  exercise  hours  grade  \
# 340        Abbot        Hall    male   16         4      3   58.9
# 388       Colton       Ochoa    male   17         1      4   60.3
# 410        Linda     Baldwin  female   16         5      2   59.0
# 528      Chester       Vance    male   17         1      5   60.1
# 556        Lacey      Nieves  female   18         1      2   57.9
# 664        Alika       Poole  female   19         2     16   32.0
# 672       Ciaran         Gay    male   19         4      3   59.3
# 700       Steven     Sherman    male   18         1      2   60.0
# 869        Tanek    Stephens    male   15         1      4   60.5
# 972       Keegan   Rasmussen    male   19         4      3   43.0
# 1068      Isaiah  Harrington    male   17         1      4   58.9
# 1207       Selma       Stout  female   19         2      3   59.4
# 1237       Willa       Byers  female   14         2      4   59.2
# ...

# %%
df[df['graderanked'] < 6].sort_values('graderanked')
# Out:
#        fname      lname  gender  age  exercise  hours  grade  \
# 664    Alika      Poole  female   19         2     16   32.0
# 972   Keegan  Rasmussen    male   19         4      3   43.0
# 1870    Levi    Coleman    male   19         3      3   55.9
# 1910    Gail     Mcneil  female   17         2      3   56.1
# 1494   Jenna     Wagner  female   16         1      3   56.3
#
#                                             address lettergrade  graderanked
# 664     9282 Purple Finch Lane, Lexington, NC 27292           F          1.0
# 972   876 East Pilgrim Street, Chelmsford, MA 01824           F          2.0
# 1870      9453 Laurel Street, Jersey City, NJ 07302           F          3.0
# 1910            8409A Spruce St., Fishers, IN 46037           F          4.0
# 1494    8829 Shore Dr., Hopewell Junction, NY 12533           F          5.0

# %%
df['hours'].max()
# Out:
# 20

# %%
df['isFailing'] = np.where(df['grade']<70,
'yes', 'no')
df.tail(10)
# Out:
#           fname     lname  gender  age  exercise  hours  grade  \
# 1990      Adena    Battle  female   17         2      8   70.2
# 1991      Craig    Obrien    male   16         3      7   64.9
# 1992   Isabelle    Barber  female   14         5      9   78.5
# 1993       Risa    Watson  female   14         2     10   74.3
# 1994    Emerson      Gill    male   17         5      5   67.5
# 1995       Cody  Shepherd    male   19         1      8   80.1
# 1996  Geraldine  Peterson  female   16         4     18  100.0
# 1997   Mercedes      Leon  female   18         3     14   84.9
# 1998     Lucius   Rowland    male   16         1      7   69.1
# 1999      Linus    Morris    male   19         4     10   79.6
#
#                                             address lettergrade  graderanked  \
# 1990    9272 Elizabeth Drive, Londonderry, NH 03053           C        214.5
# 1991             524 Park Ave., Hollywood, FL 33020           D         70.5
# ...

# %%
df['isFailingMale'] = np.where((df['grade']<70)
& (df['gender'] == 'male'),'yes', 'no')
df.tail(10)
# Out:
#           fname     lname  gender  age  exercise  hours  grade  \
# 1990      Adena    Battle  female   17         2      8   70.2
# 1991      Craig    Obrien    male   16         3      7   64.9
# 1992   Isabelle    Barber  female   14         5      9   78.5
# 1993       Risa    Watson  female   14         2     10   74.3
# 1994    Emerson      Gill    male   17         5      5   67.5
# 1995       Cody  Shepherd    male   19         1      8   80.1
# 1996  Geraldine  Peterson  female   16         4     18  100.0
# 1997   Mercedes      Leon  female   18         3     14   84.9
# 1998     Lucius   Rowland    male   16         1      7   69.1
# 1999      Linus    Morris    male   19         4     10   79.6
#
#                                             address lettergrade  graderanked  \
# 1990    9272 Elizabeth Drive, Londonderry, NH 03053           C        214.5
# 1991             524 Park Ave., Hollywood, FL 33020           D         70.5
# ...

# %%
def singlename(fn, ln):
    return fn+" "+ln

# %%
df['fullname'] = singlename(df['fname'],df['lname'])

# %%
def singlename(study, excercise):
    return study+" "+excercise
df['TotalTime'] = singlename(df['fname'],df['lname'])

# %%
import pandas as pd
Location = "H:/study/5th_semester/DataAnylasis/Assignmnet_Data_DataAnalysis_2/Assignmnet_two_data/dataset/gradedata.csv"
df = pd.read_csv(Location)
df.head()
# Out:
#      fname     lname  gender  age  exercise  hours  grade  \
# 0   Marcia      Pugh  female   17         3     10   82.4
# 1   Kadeem  Morrison    male   18         4      4   78.2
# 2     Nash    Powell    male   18         5      9   79.3
# 3  Noelani    Wagner  female   14         2      7   83.2
# 4  Noelani    Cherry  female   18         4     15   87.4
#
#                                     address
# 0   9253 Richardson Road, Matawan, NJ 07747
# 1          33 Spring Dr., Taunton, MA 02780
# 2          41 Hill Avenue, Mentor, OH 44060
# 3        8839 Marshall St., Miami, FL 33125
# 4  8304 Charles Rd., Lewis Center, OH 43035

# %%
def score_to_numeric(x):
    if x=='female':
        return 1
    if x=='male':
        return 0

# %%
df['gender_val'] = df['gender'].apply(score_to_numeric)
df.tail()
# Out:
#           fname     lname  gender  age  exercise  hours  grade  \
# 1995       Cody  Shepherd    male   19         1      8   80.1
# 1996  Geraldine  Peterson  female   16         4     18  100.0
# 1997   Mercedes      Leon  female   18         3     14   84.9
# 1998     Lucius   Rowland    male   16         1      7   69.1
# 1999      Linus    Morris    male   19         4     10   79.6
#
#                                           address  gender_val
# 1995        982 West Street, Alexandria, VA 22304           0
# 1996   78 Morris Street, East Northport, NY 11731           1
# 1997        30 Glenridge Rd., Bountiful, UT 84010           1
# 1998  342 West Meadowbrook Lane, Helena, MT 59601           0
# 1999       81 Homestead Drive, Voorhees, NJ 08043           0

# %%
df_gender = pd.get_dummies(df['gender'])
df_gender.tail()
# Out:
#       female  male
# 1995       0     1
# 1996       1     0
# 1997       1     0
# 1998       0     1
# 1999       0     1

# %%
df_new = pd.concat([df, df_gender], axis=1)
df_new.tail()
df_new = df.join(df_gender)
df_new.tail()
# Out:
#           fname     lname  gender  age  exercise  hours  grade  \
# 1995       Cody  Shepherd    male   19         1      8   80.1
# 1996  Geraldine  Peterson  female   16         4     18  100.0
# 1997   Mercedes      Leon  female   18         3     14   84.9
# 1998     Lucius   Rowland    male   16         1      7   69.1
# 1999      Linus    Morris    male   19         4     10   79.6
#
#                                           address  gender_val  female  male
# 1995        982 West Street, Alexandria, VA 22304           0       0     1
# 1996   78 Morris Street, East Northport, NY 11731           1       1     0
# 1997        30 Glenridge Rd., Bountiful, UT 84010           1       1     0
# 1998  342 West Meadowbrook Lane, Helena, MT 59601           0       0     1
# 1999       81 Homestead Drive, Voorhees, NJ 08043           0       0     1

# %%
import pandas as pd
names = ['Bob','Jessica','Mary','John','Mel']
grades = [76,95,77,78,99]
bsdegrees = [1,1,0,0,1]
msdegrees = [2,1,0,0,0]
phddegrees = [0,1,0,0,0]
GradeList = list(zip(names,grades,bsdegrees,msdegrees,
phddegrees))
columns=['Names','Grades','BS','MS','PhD']
df = pd.DataFrame(data = GradeList, columns=columns)
df
# Out:
#      Names  Grades  BS  MS  PhD
# 0      Bob      76   1   2    0
# 1  Jessica      95   1   1    1
# 2     Mary      77   0   0    0
# 3     John      78   0   0    0
# 4      Mel      99   1   0    0

# %%
df.drop('PhD', axis=1)
# Out:
#      Names  Grades  BS  MS
# 0      Bob      76   1   2
# 1  Jessica      95   1   1
# 2     Mary      77   0   0
# 3     John      78   0   0
# 4      Mel      99   1   0

# %%
df['HighSchool']=0

# %%
df['PreSchool'] = np.nan

# %%
d = ([0,1,0,1,0])
s = pd.Series(d, index= df.index)
df['DriversLicense'] = s
df
# Out:
#      Names  Grades  BS  MS  PhD  HighSchool  PreSchool  DriversLicense
# 0      Bob      76   1   2    0           0        NaN               0
# 1  Jessica      95   1   1    1           0        NaN               1
# 2     Mary      77   0   0    0           0        NaN               0
# 3     John      78   0   0    0           0        NaN               1
# 4      Mel      99   1   0    0           0        NaN               0

# %%
Location = "H:/study/5th_semester/DataAnylasis/Assignmnet_Data_DataAnalysis_2/Assignmnet_two_data/dataset/gradedata.csv"
df = pd.read_csv(Location)
df.head()
# Out:
#      fname     lname  gender  age  exercise  hours  grade  \
# 0   Marcia      Pugh  female   17         3     10   82.4
# 1   Kadeem  Morrison    male   18         4      4   78.2
# 2     Nash    Powell    male   18         5      9   79.3
# 3  Noelani    Wagner  female   14         2      7   83.2
# 4  Noelani    Cherry  female   18         4     15   87.4
#
#                                     address
# 0   9253 Richardson Road, Matawan, NJ 07747
# 1          33 Spring Dr., Taunton, MA 02780
# 2          41 Hill Avenue, Mentor, OH 44060
# 3        8839 Marshall St., Miami, FL 33125
# 4  8304 Charles Rd., Lewis Center, OH 43035

# %%
df['fname']
# Out:
# 0          Marcia
# 1          Kadeem
# 2            Nash
# 3         Noelani
# 4         Noelani
# 5            Neil
# 6           Nelle
# 7         Armando
# 8         Illiana
# 9            Neil
# 10         Daquan
# 11           Nola
# 12          Quinn
# 13        Frances
# 14        Lareina
# 15          Medge
# 16           Kibo
# 17          Libby
# 18         Shelly
# 19           Lane
# 20        Isadora
# 21          Maggy
# 22          Elton
# 23          Lance
# 24           Kyle
# 25          Colin
# 26        Solomon
# 27           Ulla
# 28          Tyler
# 29           Emma
#           ...
# 1970      Armando
# 1971        Haley
# 1972        Fritz
# 1973    Allistair
# 1974         Ella
# 1975        Felix
# 1976         Dean
# 1977      Quinlan
# 1978        Kiara
# 1979          Kai
# 1980       Maxine
# 1981         Leah
# 1982        Kalia
# 1983      Anthony
# 1984       Joshua
# 1985        Akeem
# 1986       Indigo
# 1987        Price
# 1988        Quinn
# ...

# %%
df[['fname']]
# Out:
#           fname
# 0        Marcia
# 1        Kadeem
# 2          Nash
# 3       Noelani
# 4       Noelani
# 5          Neil
# 6         Nelle
# 7       Armando
# 8       Illiana
# 9          Neil
# 10       Daquan
# 11         Nola
# 12        Quinn
# 13      Frances
# 14      Lareina
# 15        Medge
# 16         Kibo
# 17        Libby
# 18       Shelly
# 19         Lane
# 20      Isadora
# 21        Maggy
# 22        Elton
# 23        Lance
# 24         Kyle
# 25        Colin
# 26      Solomon
# 27         Ulla
# 28        Tyler
# 29         Emma
# ...         ...
# 1970    Armando
# 1971      Haley
# 1972      Fritz
# 1973  Allistair
# 1974       Ella
# 1975      Felix
# 1976       Dean
# 1977    Quinlan
# 1978      Kiara
# 1979        Kai
# 1980     Maxine
# 1981       Leah
# 1982      Kalia
# 1983    Anthony
# 1984     Joshua
# 1985      Akeem
# 1986     Indigo
# 1987      Price
# 1988      Quinn
# 1989       John
# 1990      Adena
# 1991      Craig
# 1992   Isabelle
# ...

# %%
df[['fname','age','grade']]
# Out:
#           fname  age  grade
# 0        Marcia   17   82.4
# 1        Kadeem   18   78.2
# 2          Nash   18   79.3
# 3       Noelani   14   83.2
# 4       Noelani   18   87.4
# 5          Neil   16   88.7
# 6         Nelle   17   80.2
# 7       Armando   17   95.1
# 8       Illiana   15   76.5
# 9          Neil   15   89.7
# 10       Daquan   16   85.2
# 11         Nola   15   75.3
# 12        Quinn   14   80.7
# 13      Frances   15   84.2
# 14      Lareina   18   87.6
# 15        Medge   15   75.8
# 16         Kibo   16   88.2
# 17        Libby   19  100.0
# 18       Shelly   18   84.3
# 19         Lane   19   84.2
# 20      Isadora   18   79.1
# 21        Maggy   15   90.5
# 22        Elton   16   71.0
# 23        Lance   14   90.3
# 24         Kyle   17   82.4
# 25        Colin   14   83.8
# 26      Solomon   15   94.5
# 27         Ulla   18   83.5
# 28        Tyler   16   69.7
# 29         Emma   16   91.1
# ...         ...  ...    ...
# 1970    Armando   19   93.2
# ...

# %%
df2 = df[['fname','age','grade']]
df2.head()
# Out:
#      fname  age  grade
# 0   Marcia   17   82.4
# 1   Kadeem   18   78.2
# 2     Nash   18   79.3
# 3  Noelani   14   83.2
# 4  Noelani   18   87.4

# %%
Location = "H:/study/5th_semester/DataAnylasis/Assignmnet_Data_DataAnalysis_2/Assignmnet_two_data/dataset/gradedata.csv"
df = pd.read_csv(Location)
df.head()
# Out:
#      fname     lname  gender  age  exercise  hours  grade  \
# 0   Marcia      Pugh  female   17         3     10   82.4
# 1   Kadeem  Morrison    male   18         4      4   78.2
# 2     Nash    Powell    male   18         5      9   79.3
# 3  Noelani    Wagner  female   14         2      7   83.2
# 4  Noelani    Cherry  female   18         4     15   87.4
#
#                                     address
# 0   9253 Richardson Road, Matawan, NJ 07747
# 1          33 Spring Dr., Taunton, MA 02780
# 2          41 Hill Avenue, Mentor, OH 44060
# 3        8839 Marshall St., Miami, FL 33125
# 4  8304 Charles Rd., Lewis Center, OH 43035

# %%
df.columns = ['FirstName', 'LastName', 'Gender',
'Age', 'HoursExercisePerWeek',
'HoursStudyPerWeek', 'LetterGrade',
'StreetAddress']
df.head()
# Out:
#   FirstName  LastName  Gender  Age  HoursExercisePerWeek  HoursStudyPerWeek  \
# 0    Marcia      Pugh  female   17                     3                 10
# 1    Kadeem  Morrison    male   18                     4                  4
# 2      Nash    Powell    male   18                     5                  9
# 3   Noelani    Wagner  female   14                     2                  7
# 4   Noelani    Cherry  female   18                     4                 15
#
#    LetterGrade                             StreetAddress
# 0         82.4   9253 Richardson Road, Matawan, NJ 07747
# 1         78.2          33 Spring Dr., Taunton, MA 02780
# 2         79.3          41 Hill Avenue, Mentor, OH 44060
# 3         83.2        8839 Marshall St., Miami, FL 33125
# 4         87.4  8304 Charles Rd., Lewis Center, OH 43035

# %%
headers = list(df.columns.values)

# %%
headers[0] = 'FName'
headers[1] = 'LName'
df.columns = headers
df.head()
# Out:
#      FName     LName  Gender  Age  HoursExercisePerWeek  HoursStudyPerWeek  \
# 0   Marcia      Pugh  female   17                     3                 10
# 1   Kadeem  Morrison    male   18                     4                  4
# 2     Nash    Powell    male   18                     5                  9
# 3  Noelani    Wagner  female   14                     2                  7
# 4  Noelani    Cherry  female   18                     4                 15
#
#    LetterGrade                             StreetAddress
# 0         82.4   9253 Richardson Road, Matawan, NJ 07747
# 1         78.2          33 Spring Dr., Taunton, MA 02780
# 2         79.3          41 Hill Avenue, Mentor, OH 44060
# 3         83.2        8839 Marshall St., Miami, FL 33125
# 4         87.4  8304 Charles Rd., Lewis Center, OH 43035

# %%
headers[3] = 'years'
df.head()
# Out:
#      FName     LName  Gender  Age  HoursExercisePerWeek  HoursStudyPerWeek  \
# 0   Marcia      Pugh  female   17                     3                 10
# 1   Kadeem  Morrison    male   18                     4                  4
# 2     Nash    Powell    male   18                     5                  9
# 3  Noelani    Wagner  female   14                     2                  7
# 4  Noelani    Cherry  female   18                     4                 15
#
#    LetterGrade                             StreetAddress
# 0         82.4   9253 Richardson Road, Matawan, NJ 07747
# 1         78.2          33 Spring Dr., Taunton, MA 02780
# 2         79.3          41 Hill Avenue, Mentor, OH 44060
# 3         83.2        8839 Marshall St., Miami, FL 33125
# 4         87.4  8304 Charles Rd., Lewis Center, OH 43035

# %%
df.columns = map(str.lower, df.columns)
df.columns = [x.lower() for x in df.columns]

# %%
df.columns = map(str.upper, df.columns)
df.columns = [x.upper() for x in df.columns]

# %%
names = ['Bob','Jessica','Mary','John','Mel']
grades = [76,95,77,78,99]
GradeList = list(zip(names,grades))
df = pd.DataFrame(data = GradeList,
columns=['Names', 'Grades'])
df
# Out:
#      Names  Grades
# 0      Bob      76
# 1  Jessica      95
# 2     Mary      77
# 3     John      78
# 4      Mel      99

# %%
df['Names'].str.contains('Mel')
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4     True
# Name: Names, dtype: bool

# %%
df['Names'].str.contains('Mel').any()
# Out:
# True

# %%
df['Names'].str.contains('Mel').all()
# Out:
# False

# %%
df.loc[df['Names'].str.contains('Mel')==True]
df.loc[df['Grades']==0]
# Out:
# Empty DataFrame
# Columns: [Names, Grades]
# Index: []

# %%
import pandas as pd
names = ['Bob','Jessi','Mary','John','Mel','Sam',
'Cathy','Hank','Lloyd']
grades = [76,95,77,78,99,84,79,100,73]
bsdegrees = [1,1,0,0,1,1,1,0,1]
msdegrees = [2,1,0,0,0,1,1,0,0]
phddegrees = [0,1,0,0,0,2,1,0,0]
GradeList = list(zip(names,grades,bsdegrees,msdegrees,
phddegrees))
df = pd.DataFrame(data = GradeList, columns=['Name','Grade','BS',
'MS','PhD'])
df.head(1)
# Out:
#   Name  Grade  BS  MS  PhD
# 0  Bob     76   1   2    0

# %%
names = ['Bob','Jessi','Mary','John','Mel','Sam',
'Cathy','Hank','Lloyd']
grades = [76,95,77,78,99,84,79,100,73]
bsdegrees = [1,1,0,0,1,1,1,0,1]
msdegrees = [2,1,0,0,0,1,1,0,0]
phddegrees = [0,1,0,0,0,2,1,0,0]
GradeList = list(zip(names,grades,bsdegrees,msdegrees,
phddegrees))
df = pd.DataFrame(data = GradeList, columns=['Name','Grade','BS',
'MS','PhD'])
df
df.loc[df['Name'].str.contains('MS')==True]
df.loc[df['MS']>0]
# Out:
#     Name  Grade  BS  MS  PhD
# 0    Bob     76   1   2    0
# 1  Jessi     95   1   1    1
# 5    Sam     84   1   1    2
# 6  Cathy     79   1   1    1

# %%
Location = "H:/study/5th_semester/DataAnylasis/Assignmnet_Data_DataAnalysis_2/Assignmnet_two_data/dataset/gradedata.csv"
df = pd.read_csv(Location)
df.head()
# Out:
#      fname     lname  gender  age  exercise  hours  grade  \
# 0   Marcia      Pugh  female   17         3     10   82.4
# 1   Kadeem  Morrison    male   18         4      4   78.2
# 2     Nash    Powell    male   18         5      9   79.3
# 3  Noelani    Wagner  female   14         2      7   83.2
# 4  Noelani    Cherry  female   18         4     15   87.4
#
#                                     address
# 0   9253 Richardson Road, Matawan, NJ 07747
# 1          33 Spring Dr., Taunton, MA 02780
# 2          41 Hill Avenue, Mentor, OH 44060
# 3        8839 Marshall St., Miami, FL 33125
# 4  8304 Charles Rd., Lewis Center, OH 43035

# %%
df['grade'].head()
# Out:
# 0    82.4
# 1    78.2
# 2    79.3
# 3    83.2
# 4    87.4
# Name: grade, dtype: float64

# %%
df[['age','grade']].head()
# Out:
#    age  grade
# 0   17   82.4
# 1   18   78.2
# 2   18   79.3
# 3   14   83.2
# 4   18   87.4

# %%
df[:2]
# Out:
#     fname     lname  gender  age  exercise  hours  grade  \
# 0  Marcia      Pugh  female   17         3     10   82.4
# 1  Kadeem  Morrison    male   18         4      4   78.2
#
#                                    address
# 0  9253 Richardson Road, Matawan, NJ 07747
# 1         33 Spring Dr., Taunton, MA 02780

# %%
df[df['grade'] > 80]
# Out:
#           fname      lname  gender  age  exercise  hours  grade  \
# 0        Marcia       Pugh  female   17         3     10   82.4
# 3       Noelani     Wagner  female   14         2      7   83.2
# 4       Noelani     Cherry  female   18         4     15   87.4
# 5          Neil    Whitley    male   16         5     16   88.7
# 6         Nelle     Golden  female   17         1      9   80.2
# 7       Armando    Hoffman    male   17         5     18   95.1
# 9          Neil     Wooten    male   15         3     15   89.7
# 10       Daquan    Alvarez    male   16         2     13   85.2
# 12        Quinn     Warren  female   14         4     12   80.7
# 13      Frances  Velasquez  female   15         2     15   84.2
# 14      Lareina      Poole  female   18         1     14   87.6
# 16         Kibo      Gates    male   16         1     10   88.2
# 17        Libby     Guzman  female   19         1     19  100.0
# 18       Shelly    Rosario  female   18         4     13   84.3
# ...

# %%
df.ix[(df['grade'] > 99.9) &
(df['gender'] == 'male') ]
# Out:
# C:\anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.
#           fname      lname gender  age  exercise  hours  grade  \
# 36         Ivor     Arnold   male   19         4     20  100.0
# 165      Ciaran      Johns   male   16         4     15  100.0
# 226       Uriah   Cummings   male   18         3     20  100.0
# 303       Kamal     Walton   male   14         1     17  100.0
# 325        Thor      Ramos   male   17         3     18  100.0
# 355      Kadeem   Marshall   male   17         5     18  100.0
# 382       Jacob       Gray   male   15         3     17  100.0
# 473      Declan    Manning   male   18         4     16  100.0
# 616         Ali     Franks   male   18         5     20  100.0
# ...

# %%
df.ix[(df['grade'] > 99) | (df['gender'] == 'female') ]
# Out:
# C:\anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.
#           fname      lname  gender  age  exercise  hours  grade  \
# 0        Marcia       Pugh  female   17         3     10   82.4
# 3       Noelani     Wagner  female   14         2      7   83.2
# 4       Noelani     Cherry  female   18         4     15   87.4
# 6         Nelle     Golden  female   17         1      9   80.2
# 8       Illiana      Rojas  female   15         5      9   76.5
# 11         Nola  Velazquez  female   15         2     10   75.3
# 12        Quinn     Warren  female   14         4     12   80.7
# 13      Frances  Velasquez  female   15         2     15   84.2
# ...

# %%
import pandas as pd
Location = "H:/study/5th_semester/DataAnylasis/Assignmnet_Data_DataAnalysis_2/Assignmnet_two_data/dataset/gradedata.csv"
df = pd.read_csv(Location)
df.head()
# Out:
#      fname     lname  gender  age  exercise  hours  grade  \
# 0   Marcia      Pugh  female   17         3     10   82.4
# 1   Kadeem  Morrison    male   18         4      4   78.2
# 2     Nash    Powell    male   18         5      9   79.3
# 3  Noelani    Wagner  female   14         2      7   83.2
# 4  Noelani    Cherry  female   18         4     15   87.4
#
#                                     address
# 0   9253 Richardson Road, Matawan, NJ 07747
# 1          33 Spring Dr., Taunton, MA 02780
# 2          41 Hill Avenue, Mentor, OH 44060
# 3        8839 Marshall St., Miami, FL 33125
# 4  8304 Charles Rd., Lewis Center, OH 43035

# %%
female = df['gender'] == "female"
a_student = df['grade'] >= 90
df[female & a_student].head()
# Out:
#       fname      lname  gender  age  exercise  hours  grade  \
# 17    Libby     Guzman  female   19         1     19  100.0
# 21    Maggy  Whitfield  female   15         1     15   90.5
# 29     Emma     Mccall  female   16         2     13   91.1
# 32  Georgia      Munoz  female   14         5     20   99.0
# 33    Doris   Melendez  female   17         5     12   93.2
#
#                                    address
# 17  666 S. Pennington Rd., Dover, NH 03820
# 21        2 Henry Ave., Palm Bay, FL 32907
# 29   854 Sussex Street, Westford, MA 01886
# 32     84 New Saddle St., Revere, MA 02151
# 33       8 Euclid Drive, Bel Air, MD 21014

# %%
df[df['fname'].notnull() & (df['gender'] == "male")]
# Out:
#           fname       lname gender  age  exercise  hours  grade  \
# 1        Kadeem    Morrison   male   18         4      4   78.2
# 2          Nash      Powell   male   18         5      9   79.3
# 5          Neil     Whitley   male   16         5     16   88.7
# 7       Armando     Hoffman   male   17         5     18   95.1
# 9          Neil      Wooten   male   15         3     15   89.7
# 10       Daquan     Alvarez   male   16         2     13   85.2
# 16         Kibo       Gates   male   16         1     10   88.2
# 19         Lane        Tate   male   19         4     11   84.2
# 22        Elton      Wagner   male   16         2      9   71.0
# 23        Lance    Benjamin   male   14         5     18   90.3
# 24         Kyle     Skinner   male   17         5      6   82.4
# 25        Colin       Cohen   male   14         1     10   83.8
# 26      Solomon   Mcpherson   male   15         5     18   94.5
# 28        Tyler     Collier   male   16         1      9   69.7
# ...

# %%
Location = "H:/study/5th_semester/DataAnylasis/Assignmnet_Data_DataAnalysis_2/Assignmnet_two_data/dataset/gradedata.csv"
df = pd.read_csv(Location)
df.tail()
# Out:
#           fname     lname  gender  age  exercise  hours  grade  \
# 1995       Cody  Shepherd    male   19         1      8   80.1
# 1996  Geraldine  Peterson  female   16         4     18  100.0
# 1997   Mercedes      Leon  female   18         3     14   84.9
# 1998     Lucius   Rowland    male   16         1      7   69.1
# 1999      Linus    Morris    male   19         4     10   79.6
#
#                                           address
# 1995        982 West Street, Alexandria, VA 22304
# 1996   78 Morris Street, East Northport, NY 11731
# 1997        30 Glenridge Rd., Bountiful, UT 84010
# 1998  342 West Meadowbrook Lane, Helena, MT 59601
# 1999       81 Homestead Drive, Voorhees, NJ 08043

# %%
df.take(np.random.permutation(len(df))[:100])
# Out:
#          fname        lname  gender  age  exercise  hours  grade  \
# 142       Dane        Flynn    male   18         5     12   87.4
# 483       Inez       Vargas  female   16         2     19   93.4
# 1977   Quinlan      Hawkins    male   14         3     18   85.6
# 574       Irma      Bradley  female   14         3      6   66.2
# 1156     Laura         Park  female   16         5      8   78.4
# 1129     Nasim       Stuart    male   17         1     11   72.4
# 1116     Perry       Hudson    male   18         3     10   71.8
# 1238     Naida     Carrillo  female   18         2      5   75.9
# 458       Iola    Fernandez  female   17         1     14   81.6
# 77      Quemby      Justice  female   14         2     17  100.0
# 530     Robert         Bass    male   16         4      9   73.8
# 1799     Wanda        Jones  female   16         3     14   84.7
# 1065   Nichole         Knox  female   16         3     14   84.3
# ...

# %%
df.take(np.random.permutation(len(df))[:500])
# Out:
#           fname        lname  gender  age  exercise  hours  grade  \
# 1740     Warren       Warner    male   19         1      5   62.6
# 1585      Renee       Hester  female   18         2      6   68.4
# 1726      Hyatt     Erickson    male   18         4     13   89.1
# 419    Amethyst  Christensen  female   15         5      6   80.4
# 1854     Kareem       Fisher    male   18         2     14   82.5
# 1570     Travis      Shields    male   19         4     10   86.1
# 575        Gray       Reilly    male   16         1     12   87.5
# 1736      Oscar        Mason    male   18         4     15   90.3
# 187      Ariana         Hess  female   15         4     14   99.1
# 1846      Roary         Howe  female   16         1     18   85.4
# 1240    Brandon        Myers    male   19         2     12   78.6
# 1863       Paki     Schwartz    male   17         3     16   90.6
# 1817       Vera       Molina  female   14         2     11   83.6
# ...

# %%
names = ['Bob','Jessica','Mary','John','Mel']
grades = [76,95,77,78,99]
GradeList = list(zip(names,grades))
df = pd.DataFrame(data=GradeList,
columns=['Names','Grades'])
df
# Out:
#      Names  Grades
# 0      Bob      76
# 1  Jessica      95
# 2     Mary      77
# 3     John      78
# 4      Mel      99

# %%
df['Grades'].count() 
df['Grades'].mean()
df['Grades'].std() 
df['Grades'].min() 
df['Grades'].max() 
df['Grades'].quantile(.25)
df['Grades'].quantile(.5) 
df['Grades'].quantile(.75)
# Out:
# 95.0

# %%
df['Grades'].mean()
# Out:
# 85.0

# %%
df['Grades'].mode()
# Out:
# 0    76
# 1    77
# 2    78
# 3    95
# 4    99
# dtype: int64

# %%
df['Grades'].var()
# Out:
# 122.5

# %%
df.var()
# Out:
# Grades    122.5
# dtype: float64

# %%
names = ['Bob','Jessica','Mary','John','Mel']
grades = [76,95,77,78,99]
bsdegrees = [1,1,0,0,1]
msdegrees = [2,1,0,0,0]
phddegrees = [0,1,0,0,0]

# %%
import pandas as pd
names = ['Bob','Jessica','Mary','John','Mel']
grades = [76,95,77,78,99]
bs = [1,1,0,0,1]
ms = [2,1,0,0,0]
phd = [0,1,0,0,0]
GradeList = list(zip(names,grades,bs,ms,phd))
df = pd.DataFrame(data=GradeList,
columns=['Name','Grade','BS','MS','PhD'])
df.head(1)
# Out:
#   Name  Grade  BS  MS  PhD
# 0  Bob     76   1   2    0

# %%
df.loc[df['PhD']==0].count()
# Out:
# Name     4
# Grade    4
# BS       4
# MS       4
# PhD      4
# dtype: int64

# %%
df.mean()
# Out:
# Grade    85.0
# BS        0.6
# MS        0.6
# PhD       0.2
# dtype: float64

# %%
df['MS'].mean()
# Out:
# 0.6

# %%
import pandas as pd
Location = "H:/study/5th_semester/DataAnylasis/Assignmnet_Data_DataAnalysis_2/Assignmnet_two_data/dataset/gradedata.csv"
df = pd.read_csv(Location)
df.head()
# Out:
#      fname     lname  gender  age  exercise  hours  grade  \
# 0   Marcia      Pugh  female   17         3     10   82.4
# 1   Kadeem  Morrison    male   18         4      4   78.2
# 2     Nash    Powell    male   18         5      9   79.3
# 3  Noelani    Wagner  female   14         2      7   83.2
# 4  Noelani    Cherry  female   18         4     15   87.4
#
#                                     address
# 0   9253 Richardson Road, Matawan, NJ 07747
# 1          33 Spring Dr., Taunton, MA 02780
# 2          41 Hill Avenue, Mentor, OH 44060
# 3        8839 Marshall St., Miami, FL 33125
# 4  8304 Charles Rd., Lewis Center, OH 43035

# %%
df = df.sort_values(by='age', ascending=0)
df.head()
# Out:
#         fname      lname  gender  age  exercise  hours  grade  \
# 1000    Hanna     Mooney  female   19         2     10   88.8
# 902    Steven     Graham    male   19         4     17   95.1
# 818   Colette      Rojas  female   19         4      6   73.3
# 822     Rinah   Jacobson  female   19         1      7   80.8
# 826     Hayes  Wilkinson    male   19         5      3   76.0
#
#                                          address
# 1000  8293 SW. Cedar Swamp Lane, Union, NJ 07083
# 902                90 Grove St., Camas, WA 98607
# 818      17 Pin Oak Street, Villa Park, IL 60181
# 822       737 Amherst Court, Amsterdam, NY 12010
# 826       350 Temple Court, Mason City, IA 50401

# %%
df = df.sort_values(by=['grade', 'age'],
ascending=[True, True])
df.head()
# Out:
#        fname      lname  gender  age  exercise  hours  grade  \
# 664    Alika      Poole  female   19         2     16   32.0
# 972   Keegan  Rasmussen    male   19         4      3   43.0
# 1870    Levi    Coleman    male   19         3      3   55.9
# 1910    Gail     Mcneil  female   17         2      3   56.1
# 1494   Jenna     Wagner  female   16         1      3   56.3
#
#                                             address
# 664     9282 Purple Finch Lane, Lexington, NC 27292
# 972   876 East Pilgrim Street, Chelmsford, MA 01824
# 1870      9453 Laurel Street, Jersey City, NJ 07302
# 1910            8409A Spruce St., Fishers, IN 46037
# 1494    8829 Shore Dr., Hopewell Junction, NY 12533

# %%
df = df.sort_values(by=['lname','fname','grade', 'age'],
ascending=[True,True, True,True])
df.head()
# Out:
#          fname    lname  gender  age  exercise  hours  grade  \
# 819     Athena  Acevedo  female   15         4     12   90.0
# 1458    Cedric  Acevedo    male   19         5     14   98.8
# 1770   Leandra  Acevedo  female   14         1     15   94.4
# 1439      Levi  Acevedo    male   14         2      6   63.0
# 762   Rhiannon  Acevedo  female   15         3     10   72.7
#
#                                         address
# 819           8392 Euclid Ave., Miami, FL 33125
# 1458              50 Vine Lane, Derby, KS 67037
# 1770  51 Central Drive, South Windsor, CT 06074
# 1439         87 Cooper Ave., Westland, MI 48185
# 762   451 Pendergast Street, Bartlett, IL 60103

# %%
Location = "H:/study/5th_semester/DataAnylasis/Assignmnet_Data_DataAnalysis_2/Assignmnet_two_data/dataset/gradedata.csv"
df = pd.read_csv(Location)
df.head()
df.corr()
# Out:
#                age  exercise     hours     grade
# age       1.000000 -0.003643 -0.017467 -0.007580
# exercise -0.003643  1.000000  0.021105  0.161286
# hours    -0.017467  0.021105  1.000000  0.801955
# grade    -0.007580  0.161286  0.801955  1.000000

# %%
Location = "H:/study/5th_semester/DataAnylasis/Assignmnet_Data_DataAnalysis_2/Assignmnet_two_data/dataset/flights.csv"
df = pd.read_csv(Location)
df.head()
# Out:
#    year  month  day  dep_time  dep_delay  arr_time  arr_delay carrier tailnum  \
# 0  2013      1    1     517.0        2.0     830.0       11.0      UA  N14228
# 1  2013      1    1     533.0        4.0     850.0       20.0      UA  N24211
# 2  2013      1    1     542.0        2.0     923.0       33.0      AA  N619AA
# 3  2013      1    1     554.0       -6.0     812.0      -25.0      DL  N668DN
# 4  2013      1    1     554.0       -4.0     740.0       12.0      UA  N39463
#
#    flight origin dest  air_time  distance  hour  minute
# 0    1545    EWR  IAH     227.0      1400   5.0    17.0
# 1    1714    LGA  IAH     227.0      1416   5.0    33.0
# 2    1141    JFK  MIA     160.0      1089   5.0    42.0
# 3     461    LGA  ATL     116.0       762   5.0    54.0
# 4    1696    EWR  ORD     150.0       719   5.0    54.0

# %%
Location = "H:/study/5th_semester/DataAnylasis/Assignmnet_Data_DataAnalysis_2/Assignmnet_two_data/dataset/gradedata.csv"
df = pd.read_csv(Location)
df.head()
# Out:
#      fname     lname  gender  age  exercise  hours  grade  \
# 0   Marcia      Pugh  female   17         3     10   82.4
# 1   Kadeem  Morrison    male   18         4      4   78.2
# 2     Nash    Powell    male   18         5      9   79.3
# 3  Noelani    Wagner  female   14         2      7   83.2
# 4  Noelani    Cherry  female   18         4     15   87.4
#
#                                     address
# 0   9253 Richardson Road, Matawan, NJ 07747
# 1          33 Spring Dr., Taunton, MA 02780
# 2          41 Hill Avenue, Mentor, OH 44060
# 3        8839 Marshall St., Miami, FL 33125
# 4  8304 Charles Rd., Lewis Center, OH 43035

# %%
import statsmodels.formula.api as sm
result = sm.ols(
formula='grade ~ age + exercise + hours',
data=df).fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  grade   R-squared:                       0.664
# Model:                            OLS   Adj. R-squared:                  0.664
# Method:                 Least Squares   F-statistic:                     1315.
# Date:                Wed, 01 May 2019   Prob (F-statistic):               0.00
# Time:                        20:48:21   Log-Likelihood:                -6300.7
# No. Observations:                2000   AIC:                         1.261e+04
# Df Residuals:                    1996   BIC:                         1.263e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     57.8704      1.321     43.804      0.000      55.279      60.461
# ...

# %%
result = sm.ols(
formula='grade ~ exercise + hours',
data=df).fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  grade   R-squared:                       0.664
# Model:                            OLS   Adj. R-squared:                  0.664
# Method:                 Least Squares   F-statistic:                     1973.
# Date:                Wed, 01 May 2019   Prob (F-statistic):               0.00
# Time:                        20:48:26   Log-Likelihood:                -6300.8
# No. Observations:                2000   AIC:                         1.261e+04
# Df Residuals:                    1997   BIC:                         1.262e+04
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     58.5316      0.447    130.828      0.000      57.654      59.409
# ...

# %%
pd.pivot_table(df,
index=['gender'],
aggfunc='mean',
values=['grade','hours'])

# %%
df2 = df.loc[df['age'] == 17]
pd.pivot_table(df2,
index=['gender'],
aggfunc='mean',
values=['grade','hours'],
margins='True')
# Out:
#             grade      hours
# gender
# female  83.599435  10.943503
# male    82.949721  11.268156
# All     83.272753  11.106742

# %%
df2 = df.loc[df['hours'] > 2]
pd.pivot_table(df2,
index=['grade'],
aggfunc='mean',
values=['gender','hours'],
margins='True')
# Out:
#            hours
# grade
# 32.0   16.000000
# 43.0    3.000000
# 55.9    3.000000
# 56.1    3.000000
# 56.3    3.000000
# 58.9    3.500000
# 59.2    4.000000
# 59.3    3.000000
# 59.4    3.000000
# 59.8    4.000000
# 60.1    5.000000
# 60.3    4.000000
# 60.5    3.500000
# 60.6    3.000000
# 60.8    3.500000
# 60.9    4.000000
# 61.1    4.333333
# 61.2    5.000000
# 61.3    4.000000
# 61.4    5.500000
# 61.6    5.000000
# 61.7    3.000000
# 61.8    4.000000
# 62.2    4.000000
# 62.5    3.000000
# 62.6    4.600000
# 62.7    7.000000
# 62.8    4.000000
# 63.0    6.000000
# 63.3    4.000000
# ...          ...
# 97.1   14.250000
# 97.2   14.500000
# 97.3   14.600000
# 97.4   18.000000
# 97.5   14.666667
# 97.6   14.000000
# 97.7   17.000000
# 97.8   18.500000
# 97.9   17.500000
# 98.0   18.000000
# 98.1   15.800000
# 98.2   15.000000
# 98.3   16.000000
# 98.5   13.750000
# 98.6   16.500000
# 98.7   16.500000
# 98.8   14.000000
# 98.9   15.000000
# 99.0   18.000000
# 99.1   15.666667
# ...

# %%
Location = "H:/study/5th_semester/DataAnylasis/Assignmnet_Data_DataAnalysis_2/Assignmnet_two_data/dataset/gradedata.csv"
df = pd.read_csv(Location)
df.head()
df.mode().transpose()
# Out:
#                                        0     \
# fname                                 Dolan
# lname                                Conley
# gender                               female
# age                                      17
# exercise                                  4
# hours                                    11
# grade                                   100
# address   1 Chapel Ave., Cheshire, CT 06410
#
#                                            1     \
# fname                                       NaN
# lname                                    Harvey
# gender                                     male
# age                                         NaN
# exercise                                    NaN
# hours                                       NaN
# grade                                       NaN
# address   1 Cottage Street, Rockville, MD 20850
#
#                                          2     \
# fname                                     NaN
# ...

# %%
present_data_counts = pd.DataFrame(df.count(),
columns=['Present Values'])
present_data_counts
# Out:
#           Present Values
# fname               2000
# lname               2000
# gender              2000
# age                 2000
# exercise            2000
# hours               2000
# grade               2000
# address             2000

# %%
unique_value_counts = pd.DataFrame(
    columns=['Unique Values'])
for v in list(df.columns.values):
    unique_value_counts.loc[v] = [df[v].nunique()]
    unique_value_counts

# %%
minimum_values = pd.DataFrame(columns=[
    'Minimum Values'])
for v in list(df.columns.values):
    minimum_values.loc[v] = [df[v].min()]
    minimum_values

# %%
maximum_values = pd.DataFrame(
    columns=['Maximum Values'])
for v in list(df.columns.values):
    maximum_values.loc[v] = [df[v].max()]
    maximum_values

# %%
import pandas as pd
names = ['Bob','Jessica','Mary','John','Mel']
grades = [76,83,77,78,95]
GradeList = list(zip(names,grades))
df = pd.DataFrame(data = GradeList,
columns=['Names', 'Grades'])
# %matplotlib inline
df.plot()

# %%
import matplotlib.pyplot as plt
df.plot()
displayText = "my annotation"
xloc = 1
yloc = df['Grades'].max()
xtext = 8
ytext = 0
plt.annotate(displayText,
xy=(xloc, yloc),
xytext=(xtext,ytext),
xycoords=('axes fraction', 'data'),
textcoords='offset points')
# Out:
# Text(8,0,'my annotation')

# %%
df.plot()
displayText = "my annotation"
xloc = 1
yloc = df['Grades'].max()
xtext = 8
ytext = -150
plt.annotate(displayText,
xy=(xloc, yloc),
arrowprops=dict(facecolor='black',
shrink=0.05),
             xytext=(xtext,ytext),
xycoords=('axes fraction', 'data'),
textcoords='offset points')
# Out:
# Text(8,-150,'my annotation')

# %%
df.plot()
displayText = "WOW!"
xloc = 1
yloc = df['Grades'].max()
xtext = 8
ytext = -150
plt.annotate(displayText,
xy=(xloc, yloc),
arrowprops=dict(facecolor='black',
shrink=0.05),
             xytext=(xtext,ytext),
xycoords=('axes fraction', 'data'),
textcoords='offset points')
# Out:
# Text(8,-150,'WOW!')

# %%
import matplotlib.pyplot as plt
import pandas as pd
names = ['Bob','Jessica','Mary','John','Mel']
status = ['Senior','Freshman','Sophomore','Senior',
'Junior']
grades = [76,95,77,78,99]
GradeList = list(zip(names,grades))
df = pd.DataFrame(data = GradeList,
columns=['Names', 'Grades'])
# %matplotlib inline
df.plot(kind='bar')

# %%
df2 = df.set_index(df['Names'])
df2.plot(kind="bar")

# %%
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline
names = ['Bob','Jessica','Mary','John','Mel']
grades = [76,95,77,78,99]
gender = ['Male','Female','Female','Male','Female']
status = ['Senior','Senior','Junior','Junior','Senior']
GradeList = list(zip(names,grades,gender))
df = pd.DataFrame(data = GradeList, columns=['Names', 'Grades',
'Gender'])
df.boxplot(column='Grades')

# %%
df.boxplot(by='Gender', column='Grades')

# %%
axis1 = df.boxplot(by='Gender', column='Grades')
axis1.set_ylim(0,100)
# Out:
# (0, 100)

# %%
# %matplotlib inline
Location = "H:/study/5th_semester/DataAnylasis/Assignmnet_Data_DataAnalysis_2/Assignmnet_two_data/dataset/gradedata.csv"
df = pd.read_csv(Location)
df.head()
# Out:
#      fname     lname  gender  age  exercise  hours  grade  \
# 0   Marcia      Pugh  female   17         3     10   82.4
# 1   Kadeem  Morrison    male   18         4      4   78.2
# 2     Nash    Powell    male   18         5      9   79.3
# 3  Noelani    Wagner  female   14         2      7   83.2
# 4  Noelani    Cherry  female   18         4     15   87.4
#
#                                     address
# 0   9253 Richardson Road, Matawan, NJ 07747
# 1          33 Spring Dr., Taunton, MA 02780
# 2          41 Hill Avenue, Mentor, OH 44060
# 3        8839 Marshall St., Miami, FL 33125
# 4  8304 Charles Rd., Lewis Center, OH 43035

# %%
df.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000020E72146048>,
# ...
#       dtype=object)

# %%
df.hist(column="hours")
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000020E71BAE6A0>]],
#       dtype=object)

# %%
df.hist(column="age", by="gender")
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x0000020E71C7A710>,
# ...
#       dtype=object)

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
names = ['Bob','Jessica','Mary','John','Mel']
absences = [3,0,1,0,8]
detentions = [2,1,0,0,1]
warnings = [2,1,5,1,2]
GradeList = list(zip(names,absences,detentions,warnings))
columns=['Names', 'Absences', 'Detentions','Warnings']
df = pd.DataFrame(data = GradeList, columns=columns)
df
# Out:
#      Names  Absences  Detentions  Warnings
# 0      Bob         3           2         2
# 1  Jessica         0           1         1
# 2     Mary         1           0         5
# 3     John         0           0         1
# 4      Mel         8           1         2

# %%
df['TotalDemerits'] = df['Absences'] + df['Detentions'] + df['Warnings']
df
# Out:
#      Names  Absences  Detentions  Warnings  TotalDemerits
# 0      Bob         3           2         2              7
# 1  Jessica         0           1         1              2
# 2     Mary         1           0         5              6
# 3     John         0           0         1              1
# 4      Mel         8           1         2             11

# %%
plt.pie(df['TotalDemerits'])
# Out:
# ([<matplotlib.patches.Wedge at 0x20e71da6748>,
# ...
#  [Text(0.754866,0.800111,''),
#   Text(-0.315484,1.05379,''),
#   Text(-1.03366,0.376222,''),
#   Text(-0.982996,-0.493679,''),
#   Text(0.315484,-1.05379,'')])

# %%
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline
plt.pie(df['TotalDemerits'],
labels=df['Names'],
explode=(0,0,0,0,0.15),
startangle=90,
autopct='%1.1f%%',)
plt.axis('equal')
plt.show()

# %%
dataframe = pd.DataFrame({'Col':
np.random.normal(size=200)})
plt.scatter(dataframe.index, dataframe['Col'])

# %%
Location = "H:/study/5th_semester/DataAnylasis/Assignmnet_Data_DataAnalysis_2/Assignmnet_two_data/dataset/gradedata.csv"
df = pd.read_csv(Location)
dataframe = pd.DataFrame({'Col':
np.random.normal(size=200)})
plt.scatter(dataframe.index, dataframe['Col'])
