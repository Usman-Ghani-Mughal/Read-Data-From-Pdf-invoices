# %%
import PyPDF2

# %%
pdfFileObject = open('Milk_1.pdf','rb')

# %%
pdfReader = PyPDF2.PdfFileReader(pdfFileObject)

# %%
pdfReader.numPages
# Out:
# 2

# %%
page_0 = pdfReader.getPage(0)
page_0.extractText().split(' ')
# Out:
# ['Delivery',
#  'Note',
#  '508826',
#  'for',
#  '14.6.2019',
#  'Purchase',
#  'Order',
#  '508826PERFECTION',
#  'FULL',
#  'CREAM',
#  'MILK',
#  '3L00071780',
#  '12EA',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '40.32',
#  '',
#  '',
#  '',
#  '',
#  '40.32',
#  '3.36000PERFECTION',
#  'FULL',
#  'CREAM',
#  'MILK',
#  '2L00071779',
#  '9EA',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '20.16',
#  '',
#  '',
#  '',
#  '',
#  '20.16',
#  '2.24000PAULS',
#  'FULL',
#  'CREAM',
#  'MILK',
#  'BTL',
#  '3L00012001',
#  '12EA',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '45.60',
#  '',
#  '',
#  '',
#  '',
#  '45.60',
#  '3.80000PAULS',
#  'FULL',
#  'CREAM',
#  'MILK',
#  'BTL',
#  '2L00001003',
#  '9EA',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '23.40',
#  '',
#  '',
#  '',
#  '',
#  '23.40',
#  '2.60000PAULS',
#  'FULL',
#  'CREAM',
#  'MILK',
#  'BTL',
#  '1L00015624',
#  '4EA',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '8.72',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '8.72',
# ...
