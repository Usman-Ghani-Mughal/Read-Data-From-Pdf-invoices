# %%
from tabula import read_pdf
import pandas as pd

# %%
filename = 'Invoice 1014647'
df = read_pdf(filename+'.pdf',multiple_tables=True)
df
# Out:
# [                          0   1                         2   3  \
#  0          C u s To M E r : NaN       D  EL i vE r  T o : NaN
#  1  FRIENDLY GROCER WESTMEAD NaN  FRIENDLY GROCER WESTMEAD NaN
#  2                SHOP 11-12 NaN                SHOP 11-12 NaN
#  3         24 RAILWAY PARADE NaN         24 RAILWAY PARADE NaN
#  4           WESTMEADNSW2145 NaN           WESTMEADNSW2145 NaN
#  5                       NaN NaN                       NaN NaN
#
#                                   4  \
#  0   C u s T o M E r a C C : 105826
#  1  D E L iv E r T o  a C C :105826
#  2                 o r D E r n  o :
#  3               o P E r a To r :49
#  4                              NaN
#  5               MOSTLY PAYS DRIVER
#
#                                                     5
#  0                                        TAX INVOICE
#  1                                                NaN
#  2         T r a n s a C T io n T y P E : Tax Invoice
# ...
