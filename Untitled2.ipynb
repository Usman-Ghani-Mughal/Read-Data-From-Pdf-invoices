# %%
import pandas as pd
import tabula

# %%
filename = 'Goodman 2'
dataframe_full = tabula.read_pdf(filename+'.pdf')
dataframe_full
# Out:
#               Product Description                                            MON TUE    ...    GST Amt Net Val.1
# 0                             NaN                                        17/06 18/06    ...        ($)  Incl GST
# 1                             NaN                                    Del Ret Del Ret    ...        NaN       NaN
# 2                          Docket                                         8048193045    ...        NaN       NaN
# 3                    Flat breads:                                                NaN    ...        NaN       NaN
# 4   0167506 HELG TRAD WHT WRAP P8                                                NaN    ...       0.00      3.27
# 5      0169703 HELG S HERB WRP P7                                                NaN    ...       0.00      3.27
# 6             Flat breads: TOTALS                                            0 0 0 0    ...          0      6.54
# ...
